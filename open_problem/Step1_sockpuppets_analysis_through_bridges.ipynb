# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import re
import  networkx.algorithms.community
from networkx.algorithms import bipartite
from networkx.algorithms import community
from networkx import degree_assortativity_coefficient
import powerlaw
from cdlib import viz
from cdlib.algorithms import louvain
from cdlib import algorithms
# Out:
# C:\Users\monia\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
listings = pd.read_csv("listings.csv")

# %%
#Import the net and divide in 2 set of nodes
def read_net_w(filename):
    g = nx.Graph()
    with open(filename) as f:
        f.readline()
        for l in f:
            l = l.split(",")
            g.add_node(l[0], bipartite = 0)
            g.add_node(l[1], bipartite = 1)
            g.add_edge(l[0], l[1], weight=int(l[2]))
            
    return g

g = read_net_w(f'weighted_net.csv')
top_nodes = {n for n, d in g.nodes(data=True) if d["bipartite"] == 0}
bottom_nodes = set(g) - top_nodes

# %%
from cdlib.algorithms import louvain

# %%
#Projection of the graph on houses
def my_weight(G, u, v, weight="weight"):
    w = 0
    for nbr in set(G[u]) & set(G[v]):
        w += G[u][nbr].get(weight, 1) + G[v][nbr].get(weight, 1)
    return w

G_H= bipartite.generic_weighted_projected_graph(g, list(bottom_nodes), weight_function=my_weight)

# %%
louv_coms = algorithms.louvain(G_H, weight='weight', resolution=1., randomize=False)

# %%
l=louv_coms.communities

# %%
len(l)
# Out:
# 20

# %%
for i in range(len(l)):
    for element in l[i]:
        print(list(nx.bridges(G_H.subgraph(l[i]))))
#Per ogni bridge trovato vorrei trovare il vicino, perché magari è il più simile
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# [('14622016', '17401373')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# ...

# %%
listings[listings.listing_id == 13526838]
# Out:
#      listing_id                     title                           toprow  \
# 161    13526838  Baanakkerspark amsterdam  Intero appartamento - Host: Jos
#
#                                               roominfo  \
# 161  ['4 ospiti', '2 camere da letto', '2 letti', '...
#
#                                             facilities rating  \
# 161  ['Cucina', 'Wi-fi', 'Parcheggio gratuito inclu...     []
#
#                                       link  reviewnumber
# 161  https://www.airbnb.it/rooms/13526838?  2 recensioni

# %%
listings[listings.listing_id == 24789739]
# Out:
#      listing_id                      title  \
# 162    24789739  Amsterdam Baanakkerspark.
#
#                                          toprow  \
# 162  Stanza privata in appartamento - Host: Jos
#
#                                               roominfo  \
# 162  ['2 ospiti', '1 camera da letto', '2 letti', '...
#
#                                             facilities rating  \
# 162  ['Cucina', 'Wi-fi', 'Parcheggio gratuito inclu...    5.0
#
#                                       link     reviewnumber
# 162  https://www.airbnb.it/rooms/24789739?  (10 recensioni)

# %%
la_coms = algorithms.label_propagation(G_H)

# %%
l=la_coms.communities

# %%
for i in range(len(l)):
    for element in l[i]:
        print(list(nx.bridges(G_H.subgraph(l[i]))))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# [('654931', '1583266'), ('1583266', '761411')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
nx.shortest_path(G_H, source= '654931')
# Out:
# {'654931': ['654931'],
#  '2761156': ['654931', '2761156'],
#  '25310162': ['654931', '25310162'],
#  '8874073': ['654931', '8874073'],
#  '30140860': ['654931', '30140860'],
#  '10923071': ['654931', '10923071'],
#  '29901220': ['654931', '29901220'],
#  '1583266': ['654931', '1583266'],
#  '29776071': ['654931', '29776071'],
#  '685990': ['654931', '2761156', '685990'],
#  '1986095': ['654931', '2761156', '1986095'],
#  '35377242': ['654931', '2761156', '35377242'],
#  '24628192': ['654931', '2761156', '24628192'],
#  '2763386': ['654931', '2761156', '2763386'],
#  '16804326': ['654931', '30140860', '16804326'],
#  '15726563': ['654931', '30140860', '15726563'],
#  '1605387': ['654931', '30140860', '1605387'],
#  '15110564': ['654931', '30140860', '15110564'],
#  '35464664': ['654931', '30140860', '35464664'],
#  '27523926': ['654931', '30140860', '27523926'],
#  '21188482': ['654931', '30140860', '21188482'],
#  '21744543': ['654931', '30140860', '21744543'],
# ...

# %%
listings[listings.listing_id ==29901220]
# Out:
#     listing_id                                         title  \
# 13    29901220  The Old Canal House: suite, right in center!
#
#                                               toprow  \
# 13  Stanza privata in bed and breakfast - Host: Mark
#
#                                              roominfo  \
# 13  ['2 ospiti', '1 camera da letto', '1 letto', '...
#
#                                            facilities rating  \
# 13  ['Lungomare', 'Cucina', 'Wi-fi', 'TV con via c...   4.85
#
#                                      link      reviewnumber
# 13  https://www.airbnb.it/rooms/29901220?  (109 recensioni)

# %%
listings[listings.listing_id == 29776071]
# Out:
#     listing_id                                           title  \
# 12    29776071  The Old Canal House: studio, right in center !
#
#                                               toprow  \
# 12  Stanza privata in bed and breakfast - Host: Mark
#
#                                              roominfo  \
# 12  ['2 ospiti', 'Monolocale', '1 letto', '1 bagno...
#
#                                            facilities rating  \
# 12  ['Lungomare', 'Cucina', 'Wi-fi', 'TV con via c...   4.89
#
#                                      link      reviewnumber
# 12  https://www.airbnb.it/rooms/29776071?  (142 recensioni)
